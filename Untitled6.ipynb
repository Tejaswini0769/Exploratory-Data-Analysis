# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\tejas\Downloads\FINAL_DATASET.csv")
print(df.head())
# Out:
#    image_id                                          image_url label  \
# 0         1  https://images.unsplash.com/photo-172422561835...  REAL
# 1         2  https://images.unsplash.com/photo-172422561873...  REAL
# 2         3  https://images.unsplash.com/photo-172422561834...  REAL
# 3         4  https://images.unsplash.com/photo-172422561855...  REAL
# 4         5  https://images.unsplash.com/photo-172422561823...  REAL
#
#    label_numeric   category  gender age_group    source fake_method  \
# 0              1  Authentic  Female     18-25  Unsplash         NaN
# 1              1  Authentic    Male       50+  Unsplash         NaN
# 2              1  Authentic  Female     36-50  Unsplash         NaN
# 3              1  Authentic  Female     26-35  Unsplash         NaN
# 4              1  Authentic    Male     36-50  Unsplash         NaN
#
#   image_quality resolution  confidence_score detection_difficulty  \
# 0          High  1080x1080              0.96                 Easy
# 1          High  1080x1080              0.97                 Easy
# 2          High  1080x1080              0.95                 Easy
# 3          High  1080x1080              0.89                 Easy
# 4          High  1080x1080              0.86                 Easy
#
#   dataset_split date_collected version  year
# 0         train     2026-04-24    v2.0  2026
# 1         train     2026-04-04    v2.0  2026
# 2          test     2026-02-07    v2.0  2026
# 3         train     2026-02-20    v2.0  2026
# 4         train     2026-04-12    v2.0  2026

# %%
df['date_collected'] = pd.to_datetime(df['date_collected'], errors='coerce')

resolution_parts = df['resolution'].astype(str).str.extract(r'(\d+)x(\d+)')
df['res_width'] = pd.to_numeric(resolution_parts[0], errors='coerce')
df['res_height'] = pd.to_numeric(resolution_parts[1], errors='coerce')
df['pixel_count'] = df['res_width'] * df['res_height']

# %%
print(df.shape)
print(df.isna().sum().sort_values(ascending=False).head(10))

num_summary = df.select_dtypes(include=[np.number]).describe()
print(num_summary)

cat_cols = df.select_dtypes(exclude=[np.number, 'datetime']).columns
for col in cat_cols:
    print('\n')
    print(col)
    print(df[col].value_counts(dropna=False).head(10))
# Out:
# (6557, 20)
# fake_method             2790
# image_id                   0
# confidence_score           0
# res_height                 0
# res_width                  0
# year                       0
# version                    0
# date_collected             0
# dataset_split              0
# detection_difficulty       0
# dtype: int64
#          image_id  label_numeric  confidence_score    year    res_width  \
# count  6557.00000    6557.000000       6557.000000  6557.0  6557.000000
# mean   3279.00000       0.425499          0.903741  2026.0  1047.827970
# std    1892.98719       0.494456          0.049982     0.0    27.689549
# min       1.00000       0.000000          0.800000  2026.0  1024.000000
# 25%    1640.00000       0.000000          0.860000  2026.0  1024.000000
# 50%    3279.00000       0.000000          0.910000  2026.0  1024.000000
# 75%    4918.00000       1.000000          0.950000  2026.0  1080.000000
# max    6557.00000       1.000000          0.990000  2026.0  1080.000000
#
#         res_height   pixel_count
# count  6557.000000  6.557000e+03
# mean   1047.827970  1.098710e+06
# std      27.689549  5.825881e+04
# min    1024.000000  1.048576e+06
# 25%    1024.000000  1.048576e+06
# 50%    1024.000000  1.048576e+06
# 75%    1080.000000  1.166400e+06
# max    1080.000000  1.166400e+06
#
#
# image_url
# image_url
# https://images.unsplash.com/photo-1724225618359-a1d2763326f9?crop=entropy&cs=tinysrgb&fit=max&fm=jpg&ixid=M3w5NDQwMTV8MHwxfHNlYXJjaHwxfHxodW1hbiUyMGZhY2UlMjBwb3J0cmFpdHxlbnwwfHx8fDE3NzgwNjQ2ODd8MA&ixlib=rb-4.1.0&q=80&w=1080    1
# https://api.dicebear.com/7.x/personas/jpg?seed=user1311&size=300                                                                                                                                                                   1
# https://api.dicebear.com/7.x/personas/jpg?seed=user1321&size=300                                                                                                                                                                   1
# https://api.dicebear.com/7.x/personas/jpg?seed=user1320&size=300                                                                                                                                                                   1
# https://api.dicebear.com/7.x/personas/jpg?seed=user1319&size=300                                                                                                                                                                   1
# https://api.dicebear.com/7.x/personas/jpg?seed=user1318&size=300                                                                                                                                                                   1
# https://api.dicebear.com/7.x/personas/jpg?seed=user1317&size=300                                                                                                                                                                   1
# https://api.dicebear.com/7.x/personas/jpg?seed=user1316&size=300                                                                                                                                                                   1
# https://api.dicebear.com/7.x/personas/jpg?seed=user1315&size=300                                                                                                                                                                   1
# https://api.dicebear.com/7.x/personas/jpg?seed=user1314&size=300                                                                                                                                                                   1
# Name: count, dtype: int64
#
#
# label
# label
# FAKE    3767
# REAL    2790
# Name: count, dtype: int64
#
#
# category
# category
# AI Generated    3767
# Authentic       2790
# Name: count, dtype: int64
#
#
# gender
# gender
# Unknown    4507
# Female     1033
# Male       1017
# Name: count, dtype: int64
#
#
# age_group
# age_group
# 18-25    1681
# 36-50    1670
# 26-35    1650
# 50+      1556
# Name: count, dtype: int64
#
#
# source
# source
# MultiSource    3767
# Unsplash       2790
# Name: count, dtype: int64
#
#
# fake_method
# fake_method
# StyleGAN3    3767
# NaN          2790
# Name: count, dtype: int64
#
#
# image_quality
# image_quality
# High      4350
# Medium    2207
# Name: count, dtype: int64
#
#
# resolution
# resolution
# 1024x1024    3767
# 1080x1080    2790
# Name: count, dtype: int64
#
#
# detection_difficulty
# detection_difficulty
# Easy      2790
# Hard      2461
# Medium    1306
# Name: count, dtype: int64
#
#
# dataset_split
# dataset_split
# train    4593
# test     1323
# val       641
# Name: count, dtype: int64
#
#
# version
# version
# v2.0    6557
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7, 4))
sns.countplot(data=df, x='label', order=df['label'].value_counts().index, palette='Set2')
plt.title('Class Distribution')
plt.show()
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_13632\1395638426.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='label', order=df['label'].value_counts().index, palette='Set2')

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data=df, x='confidence_score', hue='label', bins=20, kde=True, element='step')
plt.title('Confidence Score by Label')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.countplot(data=df, y='source', order=df['source'].value_counts().index, palette='viridis')
plt.title('Source Distribution')
plt.show()
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_13632\3757298935.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='source', order=df['source'].value_counts().index, palette='viridis')

# %%
plt.figure(figsize=(7, 4))
sns.countplot(data=df, x='detection_difficulty', order=['Easy', 'Medium', 'Hard'], palette='coolwarm')
plt.title('Detection Difficulty Distribution')
plt.show()
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_13632\1949540325.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='detection_difficulty', order=['Easy', 'Medium', 'Hard'], palette='coolwarm')

# %%
plt.figure(figsize=(8, 4))
sns.countplot(data=df, x='age_group', hue='label', order=['18-25', '26-35', '36-50', '50+'], palette='Set1')
plt.title('Age Group by Label')
plt.xticks(rotation=20)
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.countplot(data=df, x='gender', hue='label', palette='Set1')
plt.title('Gender by Label')
plt.show()
